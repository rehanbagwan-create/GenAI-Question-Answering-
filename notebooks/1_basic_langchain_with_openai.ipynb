# %%
#### Load Env Variable

# %%
from dotenv import load_dotenv
load_dotenv()

# %% [markdown]
# #####Connect with Google Gemini model

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# %%
res = llm.invoke("What is GenAi , explain me in short ?")

# %%
print(res.content)

# %% [markdown]
# #####Connect with OpenAi  model

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model="gpt 4o")

# %%
res = llm.invoke ("Tell me about kolhapur  , maharashtra")

# %%
print(res.content)

# %% [markdown]
# #####Static Prompts

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI(model="gemini-2.5-flash")

# %%
prompts = [
    ("system", "You are the python developer. "),  ### "system" ,"ai" ,"user"
    ("user" , "How to sort an array.")
]

res = llm.invoke(prompts)

# %%
print(res.content)

# %%
prompts = [
    ("system", "You are the java developer. "),
    ("user" , "How to sort an array.")
]

res = llm.invoke(prompts)

# %%
print(res.content)

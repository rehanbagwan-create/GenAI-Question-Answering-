# %%
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
llm = ChatGoogleGenerativeAI (model="gemini-2.5-flash")

# %%
prompts = [
    {"role":"user", "content":"Hello, My name is Rehan Bagwan"},
    {"role":"ai","content":"Hello , Rehan Bagwan ! How I can assit you today"},
    {"role":"user" , "content":"what is My name"}
]

res = llm.invoke(prompts)
res.content
# Out:
# 'Your name is Rehan Bagwan.'

# %% [markdown]
# ### Manage History

# %%
history =[]
while True :
    query = input ("user: " )
    if query.lower () in ["exit","quit" ,"bye"]:
        print("Good Bye!")
        break

    history.append({"role":"user","content":query})
    print("user: ",query)


    res = llm.invoke(history)
    history.append({"role":"ai", "content":res.content})
    print("AI: ",res.content)
# Out:
# user:  hello
# AI:  Hello! How can I help you today?
# user:  who is pm of india
# AI:  The current Prime Minister of India is **Narendra Modi**.
# user:  what os he's age
# AI:  Narendra Modi was born on September 17, 1950.
#
# As of May 2024, he is **73 years old**. He will turn 74 in September 2024.
# user:  what is python explain me in short
# AI:  In short, **Python is a popular, high-level programming language** known for its **simplicity and readability**.
#
# Think of it as a **versatile tool** that lets you tell computers what to do using code that looks a lot like plain English.
#
# **Key points:**
#
# *   **Easy to Learn:** Its clear syntax makes it beginner-friendly.
# *   **Versatile:** Used for almost anything, including web development, data analysis, artificial intelligence (AI), machine learning, automation, and more.
# *   **Powerful:** Has a huge collection of libraries and frameworks that extend its capabilities.
#
# So, it's a powerful yet easy-to-use language that's very popular across many different fields.
# user:  what is one liner function
# AI:  A "one-liner function" is exactly what it sounds like: a function whose entire definition and logic are contained within a **single line of code**.
#
# It's used for very simple, concise operations where defining a multi-line function would be unnecessarily verbose.
#
# In **Python**, the most common way to create a one-liner function is using a **`lambda` function**.
#
# **Here's a breakdown:**
#
# 1.  **Lambda Functions (Python's primary one-liner):**
#     *   They are **anonymous** (they don't have a name like `def` functions).
#     *   They can only contain a **single expression**, which is implicitly returned.
#     *   **Syntax:** `lambda arguments: expression`
#
#     **Example:**
#     ```python
#     # A lambda function that doubles a number
#     double = lambda x: x * 2
#
#     print(double(5)) # Output: 10
#     ```
#
# 2.  **Regular `def` Functions (if simple enough):**
#     While `lambda` is the typical "one-liner" in spirit, you *can* technically make a standard `def` function a one-liner if its body is very simple and fits on one line.
#
#     **Example:**
#     ```python
#     # A regular def function that returns a greeting, on one line
#     def greet(): return "Hello!"
#
#     print(greet()) # Output: Hello!
#     ```
#
# **In short:** It's a way to write a function very compactly for small, specific tasks, often to improve readability by avoiding extra lines for trivial operations.
# Good Bye!

# %%
Structured Output In LangChain

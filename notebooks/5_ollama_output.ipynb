# %%
from langchain_ollama import ChatOllama

# %%
llm = ChatOllama(model= "gemma")

# %%
res =llm.invoke("Hello, I am Rehan")
res
# Out:
# AIMessage(content="Hello Rehan! 👋 It's lovely to meet you. How can I help you today?", additional_kwargs={}, response_metadata={'model': 'gemma', 'created_at': '2026-09-19T06:08:31.6039052Z', 'done': True, 'done_reason': 'stop', 'total_duration': 116157357500, 'load_duration': 79462500, 'prompt_eval_count': 28, 'prompt_eval_duration': 25655335000, 'eval_count': 21, 'eval_duration': 90328650000, 'logprobs': None, 'model_name': 'gemma', 'model_provider': 'ollama'}, id='lc_run--01a0b846-1342-7d60-9bf2-454b6607cb1b-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 28, 'output_tokens': 21, 'total_tokens': 49})
